# %%
import pandas as pd
import numpy as np

# NLP
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import re

# ML
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

# Visualization
import matplotlib.pyplot as plt

nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/adnanaltimeemy/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/adnanaltimeemy/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
df = pd.read_csv("fightoutcomes.csv")

df.head()
# Out:
#    Unnamed: 0 age_range opp_age_range       division   sex  wins  loss  draw  \
# 0           0     15-20         25-30        cruiser  male     6     7     2
# 1           1     15-20         25-30  super feather  male    15    13     2
# 2           2     20-25         20-25        feather  male     9    35     2
# 3           3     20-25         20-25          light  male    30    28     1
# 4           4     20-25         20-25   super bantam  male     7    21     1
#
#    other  total_fights   win_rate
# 0      1            16  37.500000
# 1      1            31  48.387097
# 2      1            47  19.148936
# 3      2            61  49.180328
# 4      2            31  22.580645

# %%
for col in df.columns:
    print(f"'{col}'")
# Out:
# 'Unnamed: 0'
# 'age_range'
# 'opp_age_range'
# 'division'
# 'sex'
# 'wins'
# 'loss'
# 'draw'
# 'other'
# 'total_fights'
# 'win_rate'

# %%
print(df.columns.tolist())
# Out:
# ['Unnamed: 0', 'age_range', 'opp_age_range', 'division', 'sex', 'wins', 'loss', 'draw', 'other', 'total_fights', 'win_rate']

# %%
print(df.columns.tolist())
# Out:
# ['Unnamed: 0', 'age_range', 'opp_age_range', 'division', 'sex', 'wins', 'loss', 'draw', 'other', 'total_fights', 'win_rate']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans

# Your data
documents = [
    "I love machine learning",
    "Clustering text data is fun",
    "KMeans groups similar documents",
    "Natural language processing is powerful"
]

# Initialize
vectorizer = TfidfVectorizer(stop_words='english')
k = 2
kmeans = KMeans(n_clusters=k, random_state=42)

# Step 1: Fit + transform
X = vectorizer.fit_transform(documents)

# Step 2: Fit KMeans
kmeans.fit(X)

# Step 3: Get terms
terms = vectorizer.get_feature_names_out()

# Step 4: Print top terms per cluster
for i in range(k):
    print(f"\nCluster {i}:")
    center = kmeans.cluster_centers_[i]
    top_indices = center.argsort()[-10:][::-1]
    top_terms = [terms[ind] for ind in top_indices]
    print(top_terms)
# Out:
# Cluster 0:
# ['machine', 'love', 'learning', 'text', 'similar', 'kmeans', 'groups', 'fun', 'documents', 'data']
#
# Cluster 1:
# ['processing', 'powerful', 'natural', 'language', 'text', 'similar', 'machine', 'love', 'learning', 'kmeans']

# %%
print(df.head())
print(df.columns)
# Out:
#    Unnamed: 0 age_range opp_age_range       division   sex  wins  loss  draw  \
# 0           0     15-20         25-30        cruiser  male     6     7     2
# 1           1     15-20         25-30  super feather  male    15    13     2
# 2           2     20-25         20-25        feather  male     9    35     2
# 3           3     20-25         20-25          light  male    30    28     1
# 4           4     20-25         20-25   super bantam  male     7    21     1
#
#    other  total_fights   win_rate
# 0      1            16  37.500000
# 1      1            31  48.387097
# 2      1            47  19.148936
# 3      2            61  49.180328
# 4      2            31  22.580645
# Index(['Unnamed: 0', 'age_range', 'opp_age_range', 'division', 'sex', 'wins',
#        'loss', 'draw', 'other', 'total_fights', 'win_rate'],
#       dtype='str')

# %%
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'age_range', 'opp_age_range', 'division', 'sex', 'wins',
#        'loss', 'draw', 'other', 'total_fights', 'win_rate'],
#       dtype='str')
